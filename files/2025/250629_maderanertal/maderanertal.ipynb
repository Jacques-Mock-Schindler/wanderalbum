# %% [markdown]
# # Bristen - Golzeren

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Bristen (Talstation) |
# | Ziel | Golzeren |
# | Strecke | 6.4 km |
# | Aufstieg | 675 m |
# | Abstieg | 110 m |
# | Marschzeit | 2 h 30 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.773376, 8.731436]
path = "../../../files/2025/250629_maderanertal/250629_golzeren.gpx"
m = create_map(center, path, "Bristen - Golzeren")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9f988c8671aa05b1fcc7bd111551bd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9f988c8671aa05b1fcc7bd111551bd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9f988c8671aa05b1fcc7bd111551bd2 = L.map(
#                 &quot;map_a9f988c8671aa05b1fcc7bd111551bd2&quot;,
#                 {
#                     center: [46.773376, 8.731436],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41982592422edc28c5434dea628d7ee2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41982592422edc28c5434dea628d7ee2.addTo(map_a9f988c8671aa05b1fcc7bd111551bd2);
#
#
#             var macro_element_ddb0a74684225a027c79b2350489aa26 = L.tileLayer.wms(
#                 &quot;https://wms.geo.admin.ch/&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.swisstopo.admin.ch/\&quot;\u003eswisstopo\u003c/a\u003e&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;ch.swisstopo.pixelkarte-farbe&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: false, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_ddb0a74684225a027c79b2350489aa26.addTo(map_a9f988c8671aa05b1fcc7bd111551bd2);
#
#
#         function geo_json_f5039a79a9c19c653131acafd392aff1_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_f5039a79a9c19c653131acafd392aff1_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f5039a79a9c19c653131acafd392aff1 = L.geoJson(null, {
#                 onEachFeature: geo_json_f5039a79a9c19c653131acafd392aff1_onEachFeature,
#
#                 style: geo_json_f5039a79a9c19c653131acafd392aff1_styler,
#             ...{
# }
#         });
#
#         function geo_json_f5039a79a9c19c653131acafd392aff1_add (data) {
#             geo_json_f5039a79a9c19c653131acafd392aff1
#                 .addData(data);
#         }
#             geo_json_f5039a79a9c19c653131acafd392aff1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[8.711920755915344, 46.76601361390203], [8.71192067116499, 46.76601001620293], [8.712130397092551, 46.76602027239278], [8.712279891129583, 46.76603030087426], [8.712369620800018, 46.7660598885268], [8.712510186247528, 46.76607991196215], [8.712639812845737, 46.76608026539907], [8.712720754090697, 46.7660703654401], [8.712969514541328, 46.76607028860599], [8.713079953566194, 46.76608974812552], [8.714469517115504, 46.766550151631236], [8.714959892909974, 46.766690417192876], [8.715309681836516, 46.76680976105854], [8.715439779218286, 46.76682989811525], [8.715800315141678, 46.766850157640874], [8.715950652491301, 46.7668403792195], [8.716200354974717, 46.766879870090634], [8.716280221939087, 46.76687987614423], [8.71635069232434, 46.7668700912036], [8.716410319786519, 46.76690001273528], [8.71671967068687, 46.766970322001725], [8.716830603312701, 46.767010464333], [8.716910099610686, 46.767050059046596], [8.71707018930465, 46.76712023979053], [8.71752081764862, 46.767240246757865], [8.718189859762788, 46.76746036624536], [8.718409694731236, 46.76751008303836], [8.718810823746026, 46.767640536185354], [8.719129568897188, 46.76783038955182], [8.719230012502521, 46.767869748175144], [8.719320609234273, 46.76788042765111], [8.719349641352892, 46.767889998387545], [8.719360348302871, 46.76789977448061], [8.719410110265017, 46.76812053332105], [8.719430215191096, 46.76814010087401], [8.719480447936803, 46.76816022954881], [8.71953984349966, 46.768180255778134], [8.720090705901384, 46.76821995852515], [8.720249605830759, 46.76823976775631], [8.720340203959495, 46.768250446300954], [8.720879633445293, 46.76824978971854], [8.721190440002829, 46.76827059080824], [8.721380285453051, 46.76827025786042], [8.721450756303966, 46.76826046966016], [8.721980190835893, 46.76816995348781], [8.7220299532637, 46.768170293886214], [8.722229689359665, 46.768200437538326], [8.72233026707545, 46.76819031033665], [8.72246987791732, 46.7681698477827], [8.722849589306861, 46.768170077353716], [8.722979692742229, 46.76819020649418], [8.723319874610752, 46.76828984171152], [8.723640552721918, 46.76834021368995], [8.724389740731567, 46.76857019262388], [8.724530317354947, 46.76859020162374], [8.724630058277398, 4

# %% [markdown]
# # Balzers - Guscha - Malans

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Balzers |
# | Ziel | Malans |
# | Strecke | 16.4 km |
# | Aufstieg | 850 m |
# | Abstieg | 790 m |
# | Marschzeit | 5 h 20 |
